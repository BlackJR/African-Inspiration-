# %%
import pandas as pd 
from matplotlib import pyplot as plt
import numpy as np

from scipy.signal import find_peaks

#df= pd.read_excel('data.xlsx',sheet_name=1)
#df= pd.read_excel('1erjuillet.xlsx',sheet_name=3)
#affiche le tableau de la feuille 3

df= pd.read_excel('data.csv', engine='xlrd')
df
# Out:
# ---------------------------------------------------------------------------
# XLRDError                                 Traceback (most recent call last)
# /var/folders/f0/_g4ppxss1ls17px_wndbbk7w0000gn/T/ipykernel_49864/117330840.py in <module>
#       9 #affiche le tableau de la feuille 3
#      10
# ---> 11 df= pd.read_excel('data.csv', engine='xlrd')
#      12 df
#
# /usr/local/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...
